# %%
# Imports

import pandas as pd
import numpy as np
import os
import csv
import warnings
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.metrics import accuracy_score
from sklearn.linear_model import RidgeClassifierCV
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression
from sktime.classification.shapelet_based import MrSEQLClassifier
from sktime.transformations.panel.rocket import Rocket, MiniRocket
from sktime.datatypes._panel._convert import from_2d_array_to_nested

warnings.filterwarnings('ignore')
pd.set_option("display.max_rows", 100)

# %%
# Opening up file containing GWAS data and reading in

file = open("Second_GWAS/Second_GWAS_Add.raw", "r")
lines = file.readlines()
len(lines)
# Out:
# 110

# %%
# Loading GWAS data into DF in the correct format

columns = lines[0].strip("\n").split(" ")
columns = [n.split("_", 1)[0] for n in columns]

df = pd.DataFrame(columns=columns)
data = []

for line in lines[1:]:
    newRow = line.strip("\n").split(" ")
    for position in range(0, len(newRow)):
        if newRow[position] == "0":
            newRow[position] = "2"
        elif newRow[position] == "2":
            newRow[position] = "0"
        
    data.append(newRow)

df = pd.DataFrame(data, columns=columns)

# %%
# Checking to see split between cases and controls

df["PHENOTYPE"].value_counts()
# Out:
# 1    55
# 0    54
# Name: PHENOTYPE, dtype: int64

# %%
# Printing shape of df

df.shape
# Out:
# (109, 41313)

# %%
# Printing shape of df

df.columns
# Out:
# Index(['FID', 'IID', 'PAT', 'MAT', 'SEX', 'PHENOTYPE', 'rs7433861',
#        'rs1166974', 'rs1166975', 'rs10446372',
#        ...
#        'rs4030335', 'rs7374010', 'rs9877345', 'rs7373662', 'rs12630742',
#        'rs11916265', 'rs7374354', 'rs9325418', 'rs9325420', 'rs10154902'],
#       dtype='object', length=41313)

# %%
# Re-encoding the phenotype as case and control

df["PHENOTYPE"] = df["PHENOTYPE"].replace("0","case")
df["PHENOTYPE"] = df["PHENOTYPE"].replace("1","control")

# %%
# Dropping columns and seperating phenotype column

phenotype = df.pop("PHENOTYPE")
dfTest = df.drop(columns=["FID","IID","PAT","MAT","SEX"])

# %%
# Replacing missing values in df with most common allele for that given SNP

imp = SimpleImputer(missing_values="NA", strategy="most_frequent")
idf = pd.DataFrame(imp.fit_transform(dfTest))
idf.columns = dfTest.columns

# %%
# Converting columns to be numberical

dfTest = idf.apply(pd.to_numeric)

# %%
# Visualising first 100 SNPs of first case

dfTranspose = dfTest.T
plt.xticks([])
plt.plot(dfTranspose[0][0:100], color="tab:blue")
phenotype[0]
# Out:
# 'case'

# %%
# Classifying entrire set of GWAS data using RandomForest

results = []
for n in range(0,10):
    xTrain, xTtest, yTrain, yTest = train_test_split(dfTest, phenotype, train_size=0.7)
    
    rfc = RandomForestClassifier()
    rfc.fit(xTrain, yTrain)
    
    yPredicted = rfc.predict(xTtest)
    results.append(accuracy_score(yTest, yPredicted))
    
print(f"Average accuracy for RandomForest on entire dataset: {sum(results) / len(results)}")
# Out:
# Average accuracy for RandomForest on entire dataset: 0.5575757575757574

# %%
# Converting df to array structure

dfTestSeries = from_2d_array_to_nested(dfTest)

# %%
# Classifying GWAS data using MiniRocket

results = []
for n in range(0,10):
    xTrain, xTest, yTrain, yTest = train_test_split(dfTestSeries, phenotype, train_size=0.7)
    minirocket = MiniRocket()
    minirocket.fit(xTrain)
    xTrainTransform = minirocket.transform(xTrain)

    classifier = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True)
    classifier.fit(xTrainTransform, yTrain)

    xTestTransform = minirocket.transform(xTest)
    yPredict = classifier.predict(xTestTransform)

    results.append(accuracy_score(yTest, yPredict))
    
print(f"Average accuracy for MiniRocket on entire dataset: {sum(results) / len(results)}")
# Out:
# Average accuracy for MiniRocket on entire dataset: 0.4545454545454545

# %%
# Classifying entrire set of GWAS data using RandomForest

results = []
for n in range(0,10):
    xTrain, xTtest, yTrain, yTest = train_test_split(dfTest, phenotype, train_size=0.7)
    
    rfc = LogisticRegression()
    rfc.fit(xTrain, yTrain)
    
    yPredicted = rfc.predict(xTtest)
    results.append(accuracy_score(yTest, yPredicted))
    
print(f"Average accuracy for RandomForest on entire dataset: {sum(results) / len(results)}")
# Out:
# Average accuracy for RandomForest on entire dataset: 0.5515151515151514

# %%
# List of SNPs with low p-values

SNPS = ['rs9867035', 'rs7638693', 'rs9837776', 'rs2873392', 'rs6792542',
       'rs1600058', 'rs1580295', 'rs1316579', 'rs834856', 'rs7430111',
       'rs9817983', 'rs2085079', 'rs834858', 'rs834843', 'rs834864',
       'rs9855684', 'rs1598120', 'rs6445172', 'rs9853565', 'rs1097157']

SNPS2 = ['rs1399796', 'rs7639777', 'rs1390752', 'rs653294', 'rs4398446',
       'rs2861837', 'rs775689', 'rs9836606', 'rs1027179', 'rs4857658',
       'rs16862262', 'rs950636', 'rs1399797', 'rs9875749', 'rs6787082',
       'rs1316658', 'rs9855655', 'rs35868010', 'rs9309910', 'rs6771942']

# %%
# Classifying GWAS data of low p-value SNPs using RandomForest

results = []
for n in range(0,10):
    xTrain, xTtest, yTrain, yTest = train_test_split(dfTest[SNPS2], phenotype, train_size=0.7)
    
    rfc = RandomForestClassifier()
    rfc.fit(xTrain, yTrain)
    
    yPredicted = rfc.predict(xTtest)
    results.append(accuracy_score(yTest, yPredicted))
    
print(f"Average accuracy for RandomForest on selected SNPs: {sum(results) / len(results)}")
# Out:
# Average accuracy for RandomForest on selected SNPs: 0.7757575757575759

# %%
rfc.feature_importances_,dfTest[SNPS].columns
# Out:
# (array([0.06962376, 0.0572558 , 0.056972  , 0.10612928, 0.2147023 ,
#         0.02854125, 0.0298844 , 0.0364137 , 0.01619224, 0.04175269,
#         0.0412927 , 0.02309266, 0.02099106, 0.01341662, 0.02889268,
#         0.06254006, 0.02588407, 0.04072761, 0.05304114, 0.03265396]),
#  Index(['rs9867035', 'rs7638693', 'rs9837776', 'rs2873392', 'rs6792542',
#         'rs1600058', 'rs1580295', 'rs1316579', 'rs834856', 'rs7430111',
#         'rs9817983', 'rs2085079', 'rs834858', 'rs834843', 'rs834864',
#         'rs9855684', 'rs1598120', 'rs6445172', 'rs9853565', 'rs1097157'],
#        dtype='object'))

# %%
# Plotting feature importance of selected SNPs from RandomForest

sorted_idx = rfc.feature_importances_.argsort()
plt.barh(dfTest[SNPS2].columns[sorted_idx[:10]], rfc.feature_importances_[sorted_idx[:10]])
# Out:
# <BarContainer object of 10 artists>

# %%
# Classifying GWAS data of low p-value SNPs using MiniRocket

dfTestSeries = from_2d_array_to_nested(dfTest[SNPS2])
results = []

for n in range(0,10):
    xTrain, xTest, yTrain, yTest = train_test_split(dfTestSeries, phenotype, train_size=0.7, random_state=1)
    minirocket = MiniRocket()
    minirocket.fit(xTrain)
    xTrainTransform = minirocket.transform(xTrain)

    classifier = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True)
    classifier.fit(xTrainTransform, yTrain)

    xTestTransform = minirocket.transform(xTest)
    yPredict = classifier.predict(xTestTransform)

    results.append(accuracy_score(yTest, yPredict))
    
print(f"Average accuracy for MiniRocket on selected SNPs: {sum(results) / len(results)}")
# Out:
# Average accuracy for MiniRocket on selected SNPs: 0.8090909090909092

# %%
# Method to generate moving window accuracy along genome using MiniRocket

def GenerateSlidingWindowsTest(runs, windowSize, useThreshold, classifierType, threshold=0):

    results = {}
    numberOfWindows = len(dfTest.columns) - windowSize
    
    xTrain, xTest, yTrain, yTest = train_test_split(dfTest, phenotype, train_size=0.7, random_state=1)
    
    for k in range(1,runs+1):

        print(f"Run {k}")

        validationScores = []
        testScores = []
        
        xTrainSplit, xValidate, yTrainSplit, yValidate = train_test_split(xTrain, yTrain, train_size=0.7)

        for n in range(0,numberOfWindows):

            if(n%(numberOfWindows//10) == 0 and n != 0):
                print(f"Progress: {round((n/numberOfWindows) * 100)}%")
                
            windowStart = n
            windowEnd = windowStart + windowSize
            xTrainWindow = xTrainSplit.iloc[:,windowStart:windowEnd]
            xValidateWindow = xValidate.iloc[:,windowStart:windowEnd]
            
            if (classifierType == "miniRocket"):
                xTrainWindowSeries = from_2d_array_to_nested(xTrainWindow)
                xValidateWindowSeries = from_2d_array_to_nested(xValidateWindow)

                minirocket = MiniRocket()
                minirocket.fit(xTrainWindowSeries)
                xTrainTransform = minirocket.transform(xTrainWindowSeries)

                classifier = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True)
                classifier.fit(xTrainTransform, yTrainSplit)

                xTestTransform = minirocket.transform(xValidateWindowSeries)

                score = classifier.score(xTestTransform,yValidate)
            
            
            elif (classifierType == "RandomForest"):
                rfc = RandomForestClassifier()
                rfc.fit(xTrainWindow, yTrainSplit)
                yPredicted = rfc.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
                
            elif (classifierType == "GaussianNB"):
                clf = GaussianNB()
                clf.fit(xTrainWindow, yTrainSplit)
                yPredicted = clf.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
                
            elif (classifierType == "LogisticRegression"):
                clf = LogisticRegression()
                clf.fit(xTrainWindow, yTrainSplit)
                yPredicted = clf.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
            
            validationScores.append(score)
            
        if useThreshold:
            windowsAboveThreshold = [n for n in validationScores if validationScores[n] > threshold]

            print(windowsAboveThresholdAfterTest)

            for window in validationScores:
                if window in results:
                    results[window] += 1#
                else:
                    results[window] = 1
        else:
            for n in range(0,numberOfWindows):
                if n in results:
                    results[n] += validationScores[n]
                else:
                    results[n] = validationScores[n]
                    
    for n in range(0,numberOfWindows):
        results[n] = results[n] / runs
        
    sortedResults = sorted(results.items(), key=lambda x: x[1], reverse=True)
    
    updatedKeyResults = {}
    for key, value in results.items():
        newKeyStart = key
        newKeyEnd = newKeyStart + windowSize
        updatedKeyResults[f"{newKeyStart}:{newKeyEnd}"] = value
        
    sortedResults = sorted(updatedKeyResults.items(), key=lambda x: x[1], reverse=True)
    return sortedResults

# %%
RandomForstSlidingWindows50 = GenerateSlidingWindowsTest(1, 50,False, "RandomForest")
# Out:
# Run 1
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%

# %%
# Method to generate sliding window accuracy along genome using MiniRocket

def GenerateWindowsTest(runs, windowSize, useThreshold, classifierType, threshold=0):

    results = {}
    numberOfWindows = len(dfTest.columns) // windowSize
    xTrain, xTest, yTrain, yTest = train_test_split(dfTest, phenotype, train_size=0.7, random_state=1)
    for k in range(1,runs+1):

        print(f"Run {k}")

        validationScores = []
        testScores = []
        
        xTrainSplit, xValidate, yTrainSplit, yValidate = train_test_split(xTrain, yTrain, train_size=0.7)

        for n in range(0,numberOfWindows):

            if(n%(numberOfWindows//10) == 0 and n != 0):
                print(f"Progress: {round((n/numberOfWindows) * 100)}%")
                
            windowStart = n * windowSize
            windowEnd = windowStart + windowSize
            xTrainWindow = xTrainSplit.iloc[:,windowStart:windowEnd]
            xValidateWindow = xValidate.iloc[:,windowStart:windowEnd]
            
            if (classifierType == "miniRocket"):
                xTrainWindowSeries = from_2d_array_to_nested(xTrainWindow)
                xValidateWindowSeries = from_2d_array_to_nested(xValidateWindow)

                minirocket = MiniRocket()
                minirocket.fit(xTrainWindowSeries)
                xTrainTransform = minirocket.transform(xTrainWindowSeries)

                classifier = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True)
                classifier.fit(xTrainTransform, yTrainSplit)

                xTestTransform = minirocket.transform(xValidateWindowSeries)

                score = classifier.score(xTestTransform,yValidate)
            
            
            elif (classifierType == "RandomForest"):
                rfc = RandomForestClassifier()
                rfc.fit(xTrainWindow, yTrainSplit)
                yPredicted = rfc.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
                
            elif (classifierType == "GaussianNB"):
                clf = GaussianNB()
                clf.fit(xTrainWindow, yTrainSplit)
                yPredicted = clf.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
                
            elif (classifierType == "LogisticRegression"):
                clf = LogisticRegression()
                clf.fit(xTrainWindow, yTrainSplit)
                yPredicted = clf.predict(xValidateWindow)
                score = accuracy_score(yPredicted, yValidate)
            
            validationScores.append(score)
            
        if useThreshold:
            windowsAboveThreshold = [n for n in validationScores if validationScores[n] > threshold]

            print(windowsAboveThresholdAfterTest)

            for window in validationScores:
                if window in results:
                    results[window] += 1#
                else:
                    results[window] = 1
        else:
            for n in range(0,numberOfWindows):
                if n in results:
                    results[n] += validationScores[n]
                else:
                    results[n] = validationScores[n]
                    
    for n in range(0,numberOfWindows):
        results[n] = results[n] / runs
        
    sortedResults = sorted(results.items(), key=lambda x: x[1], reverse=True)
    
    updatedKeyResults = {}
    for key, value in results.items():
        newKeyStart = key*windowSize
        newKeyEnd = newKeyStart + windowSize
        updatedKeyResults[f"{newKeyStart}:{newKeyEnd}"] = value
        
    sortedResults = sorted(updatedKeyResults.items(), key=lambda x: x[1], reverse=True)
    return sortedResults

# %%
# Generating accuracy for different window sizes

#MiniRocketWindows25 = GenerateWindowsTest(10, 25 ,False, "miniRocket")
#MiniRocketWindows50 = GenerateWindowsTest(10, 50 ,False, "miniRocket")
#MiniRocketWindows100 = GenerateWindowsTest(10, 100 ,False, "miniRocket")

#RandomForstWindows100 = GenerateWindowsTest(10, 100,False, "RandomForest")
#RandomForstWindows50 = GenerateWindowsTest(10, 50,False, "RandomForest")
#RandomForstWindows25 = GenerateWindowsTest(10, 25,False, "RandomForest")
#RandomForstWindows10 = GenerateWindowsTest(10, 10 ,False, "RandomForest")
#RandomForstWindows1 = GenerateWindowsTest(10, 1 ,False, "RandomForest")

#GaussianNBWindows100 = GenerateWindowsTest(1, 100,False, "GaussianNB")
#GaussianNBWindows50 = GenerateWindowsTest(10, 50,False, "GaussianNB")
#GaussianNBWindows25 = GenerateWindowsTest(10, 25,False, "GaussianNB")
#GaussianNBWindows10 = GenerateWindowsTest(10, 10 ,False, "GaussianNB")
#GaussianNBWindows1 = GenerateWindowsTest(10, 1 ,False, "GaussianNB")

LogisticRegressionWindows25 = GenerateWindowsTest(10, 25 ,False, "LogisticRegression")
LogisticRegressiontWindows50 = GenerateWindowsTest(10, 50 ,False, "LogisticRegression")
#LogisticRegressionWindows100 = GenerateWindowsTest(10, 100 ,False, "LogisticRegression")
# Out:
# Run 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10340/1038012646.py in <module>
#      17 #GaussianNBWindows1 = GenerateWindowsTest(10, 1 ,False, "GaussianNB")
#      18
# ---> 19 LogisticRegressionWindows25 = GenerateWindowsTest(10, 25 ,False, "LogisticRegression")
#      20 LogisticRegressiontWindows50 = GenerateWindowsTest(10, 50 ,False, "LogisticRegression")
#      21 #LogisticRegressionWindows100 = GenerateWindowsTest(10, 100 ,False, "LogisticRegression")
#
# ~\AppData\Local\Temp/ipykernel_10340/3832190814.py in GenerateWindowsTest(runs, windowSize, useThreshold, classifierType, threshold)
#      55             elif (classifierType == "LogisticRegression"):
#      56                 clf = LogisticRegression()
# ---> 57                 clf.fit(xTrainWindow, yTrainSplit)
#      58                 yPredicted = clf.predict(xValidateWindow)
#      59                 score = accuracy_score(yPredicted, yValidate)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %%
# Method to plot accuracies of sliding windows

def plotWindowAccuracy(windowToPlot):
    
    sortedWindows = []
    for n in range(len(windowToPlot)):
        window = windowToPlot[n]
        key, value = window[0], window[1]
        key = int(key.split(":")[1])
        sortedWindows.append((key,value))
        
    sortedFirst = sorted(sortedWindows, key=lambda tup: tup[0])
    keys, values = [],[]
    for n in range(len(sortedFirst)):
        keys.append(sortedFirst[n][0])
        values.append(sortedFirst[n][1])
        
    figure(figsize=(20, 6), dpi=80)
    plt.plot(keys, values, "-")

# %%
def recoredResults(windows, location, nameOfFile):
    if not os.path.exists(location):
        os.makedirs(location)
        
    with open(os.path.join(location, nameOfFile+".csv"), "w+") as file:
        csv_out=csv.writer(file)
        csv_out.writerow(['window','accuracy'])
        for row in windows:
            csv_out.writerow(row)

# %%
def readResults(nameOfFile):
    if not os.path.exists(nameOfFile):
        print("Cannot find file")
        
    else:
        entries = []
        with open(nameOfFile,newline='') as file:
            csvOut=csv.reader(file,delimiter=',')
            for row in csvOut:
                if not row == ['window', 'accuracy'] and row:
                    index = row[0]
                    value = float(row[1])
                    entry = (index, value)
                    entries.append(entry)
        return entries

# %%
n = readResults("Results/RandomForst/RandomForest50Window.csv")

# %%
n
# Out:
# [('1700:1750', 0.6956521739130435),
#  ('32500:32550', 0.691304347826087),
#  ('36650:36700', 0.6869565217391306),
#  ('12150:12200', 0.6826086956521739),
#  ('24650:24700', 0.6782608695652173),
#  ('14350:14400', 0.6739130434782608),
#  ('12800:12850', 0.6652173913043478),
#  ('1650:1700', 0.6521739130434783),
#  ('14150:14200', 0.6478260869565218),
#  ('5300:5350', 0.6478260869565217),
#  ('32100:32150', 0.6478260869565217),
#  ('7000:7050', 0.6434782608695652),
#  ('37050:37100', 0.6391304347826087),
#  ('17900:17950', 0.6391304347826086),
#  ('8750:8800', 0.6347826086956523),
#  ('21500:21550', 0.6347826086956522),
#  ('11600:11650', 0.6304347826086957),
#  ('25900:25950', 0.6304347826086957),
#  ('36750:36800', 0.6304347826086957),
#  ('2900:2950', 0.6304347826086956),
#  ('12300:12350', 0.6260869565217392),
#  ('1600:1650', 0.6217391304347826),
#  ('8050:8100', 0.6217391304347826),
#  ('24600:24650', 0.6217391304347826),
#  ('29400:29450', 0.6217391304347826),
#  ('32900:32950', 0.6217391304347826),
#  ('6550:6600', 0.6173913043478262),
#  ('1750:1800', 0.6173913043478261),
#  ('19150:19200', 0.617391304347826),
#  ('21800:21850', 0.617391304347826),
#  ('2950:3000', 0.6130434782608696),
#  ('5950:6000', 0.6130434782608696),
#  ('7100:7150', 0.6130434782608696),
#  ('450:500', 0.6043478260869565),
#  ('8700:8750', 0.6),
#  ('23800:23850', 0.5999999999999999),
#  ('32850:32900', 0.5999999999999999),
#  ('9850:9900', 0.5956521739130436),
#  ('12350:12400', 0.5956521739130436),
#  ('13650:13700', 0.5956521739130436),
#  ('19250:19300', 0.5956521739130435),
#  ('20350:20400', 0.5956521739130435),
#  ('26800:26850', 0.5956521739130435),
#  ('30800:30850', 0.5956521739130435),
#  ('33750:33800', 0.5956521739130435),
#  ('27000:27050', 0.5956521739130434),
#  ('16400:16450', 0.591304347826087),
#  ('29300:29350', 0.591304347826087),
#  ('33400:33450', 0.591304347826087),
#  ('36300:36350', 0.591304347826087),
#  ('3000:3050', 0.5913043478260869),
#  ('6400:6450', 0.5913043478260869),
#  ('14000:14050', 0.5913043478260869),
#  ('17500:17550', 0.5913043478260869),
#  ('19600:19650', 0.5913043478260869),
#  ('23300:23350', 0.5913043478260869),
#  ('39000:39050', 0.5913043478260869),
#  ('14050:14100', 0.5869565217391305),
#  ('9200:9250', 0.5869565217391304),
#  ('9300:9350', 0.5869565217391304),
#  ('29100:29150', 0.5869565217391304),
#  ('31600:31650', 0.5869565217391304),
#  ('19650:19700', 0.582608695652174),
#  ('25650:25700', 0.582608695652174),
#  ('1000:1050', 0.5826086956521739),
#  ('4900:4950', 0.5826086956521739),
#  ('15300:15350', 0.5826086956521739),
#  ('33950:34000', 0.3695652173913044),
#  ('19000:19050', 0.3695652173913043),
#  ('16600:16650', 0.36521739130434777),
#  ('24450:24500', 0.36086956521739133),
#  ('38250:38300', 0.35217391304347834),
#  ('550:600', 0.3521739130434783),
#  ('25200:25250', 0.3521739130434782),
#  ('29350:29400', 0.33913043478260874),
#  ('16500:16550', 0.3391304347826086),
#  ('4700:4750', 0.3260869565217391)]

# %%
recoredResults(RandomForstWindows100, "Results/RandomForst", "RandomForest100Window")
recoredResults(RandomForstWindows50, "Results/RandomForst", "RandomForest50Window")
recoredResults(RandomForstWindows25, "Results/RandomForst", "RandomForest25Window")
recoredResults(RandomForstWindows10, "Results/RandomForst", "RandomForest10Window")
recoredResults(RandomForstWindows1, "Results/RandomForst", "RandomForest1Window")

recoredResults(GaussianNBWindows100, "Results/GaussianNB", "GaussianNB100Window")
recoredResults(GaussianNBWindows50, "Results/GaussianNB", "GaussianNB50Window")
recoredResults(GaussianNBWindows25, "Results/GaussianNB", "GaussianNB25Window")
recoredResults(GaussianNBWindows10, "Results/GaussianNB", "GaussianNB10Window")
recoredResults(GaussianNBWindows1, "Results/GaussianNB", "GaussianNB1Window")

recoredResults(MiniRocketWindows100, "Results/MiniRocket", "MiniRocket100Windows")
recoredResults(MiniRocketWindows50, "Results/MiniRocket", "MiniRocket50Windows")
recoredResults(MiniRocketWindows25, "Results/MiniRocket", "MiniRocket25Windows")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1776/1190898032.py in <module>
# ----> 1 recoredResults(RandomForstWindows100, "Results/RandomForst", "RandomForest100Window")
#       2 recoredResults(RandomForstWindows50, "Results/RandomForst", "RandomForest50Window")
#       3 recoredResults(RandomForstWindows25, "Results/RandomForst", "RandomForest25Window")
#       4 recoredResults(RandomForstWindows10, "Results/RandomForst", "RandomForest10Window")
#       5 recoredResults(RandomForstWindows1, "Results/RandomForst", "RandomForest1Window")
#
# NameError: name 'recoredResults' is not defined

# %%
plotWindowAccuracy(RandomForstSlidingWindows50)

# %%
plotWindowAccuracy(GaussianNBWindows1)

# %%
plotWindowAccuracy(RandomForstWindows10)

# %%
# Classifying selected window of GWAS data using RandomForest

results = []
for n in range(0,10):
    xTrain, xTtest, yTrain, yTest = train_test_split(dfTest.iloc[:, np.r_[1650:1725]], phenotype, train_size=0.7, random_state=2)
    
    rfc = RandomForestClassifier()
    rfc.fit(xTrain, yTrain)
    
    yPredicted = rfc.predict(xTtest)
    results.append(accuracy_score(yTest, yPredicted))
    
print(f"Average accuracy for RandomForest on selected SNP window: {sum(results) / len(results)}")
# Out:
# Average accuracy for RandomForest on selected SNP window: 0.6969696969696971

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(yTest, yPredicted))
# Out:
# [[ 8  5]
#  [ 4 16]]

# %%
rfc.feature_importances_,dfTest.iloc[:, np.r_[1650:1725]].columns
# Out:
# (array([0.0139227 , 0.0114729 , 0.02975404, 0.04808537, 0.00151616,
#         0.00644573, 0.00536734, 0.00247454, 0.00335511, 0.01107487,
#         0.00363608, 0.00391857, 0.00195922, 0.00283502, 0.00590422,
#         0.01855481, 0.03913847, 0.02745767, 0.00273209, 0.00457633,
#         0.0256146 , 0.00189424, 0.02557798, 0.00241108, 0.03360537,
#         0.00803288, 0.00337867, 0.00577005, 0.01088755, 0.01167291,
#         0.02610301, 0.03868386, 0.02413516, 0.02421571, 0.02012962,
#         0.00624159, 0.0140163 , 0.01128583, 0.00980217, 0.02257766,
#         0.00829728, 0.00366092, 0.00359776, 0.00629088, 0.01721403,
#         0.00832973, 0.01991602, 0.01537697, 0.00414097, 0.011135  ,
#         0.00907277, 0.00884291, 0.00474303, 0.00582932, 0.00185055,
#         0.00579762, 0.00674713, 0.02415251, 0.02452854, 0.01892761,
#         0.00381898, 0.02463315, 0.02002998, 0.03741594, 0.00480677,
#         0.01967251, 0.04099528, 0.00128317, 0.00445172, 0.00544642,
#         0.0075091 , 0.00253956, 0.04161654, 0.00280865, 0.00430318]),
#  Index(['rs11127780', 'rs10865598', 'rs2317203', 'rs2085079', 'rs6806513',
#         'rs716764', 'rs716763', 'rs6785245', 'rs834854', 'rs1869517',
#         'rs1584882', 'rs12637514', 'rs834895', 'rs1072655', 'rs1598118',
#         'rs834856', 'rs834858', 'rs834864', 'rs4449331', 'rs1477826',
#         'rs17019957', 'rs834872', 'rs17019960', 'rs834879', 'rs834880',
#         'rs834884', 'rs10433516', 'rs17019975', 'rs6784876', 'rs17019986',
#         'rs1598120', 'rs1097157', 'rs2873392', 'rs1840290', 'rs834843',
#         'rs834840', 'rs7642215', 'rs1580295', 'rs1007414', 'rs7619063',
#         'rs1600058', 'rs1600057', 'rs11924506', 'rs7639667', 'rs7617556',
#         'rs7639998', 'rs7640085', 'rs2169641', 'rs9883719', 'rs1382066',
#         'rs2054402', 'rs6783510', 'rs2219740', 'rs28549095', 'rs6548843',
#         'rs1973163', 'rs7434172', 'rs12714541', 'rs1382069', 'rs6548846',
#         'rs10511099', 'rs1351039', 'rs9883093', 'rs11712238', 'rs13099485',
#         'rs1351036', 'rs9875791', 'rs7621875', 'rs13084603', 'rs6805632',
#         'rs7611107', 'rs4553986', 'rs4398446', 'rs9870034', 'rs9815966'],
#        dtype='object'))

# %%
# Plotting feature importance of selected window from RandomForest

sorted_idx = rfc.feature_importances_.argsort()
plt.barh(dfTest.iloc[:, np.r_[1650:1750,32100:32125]].columns[sorted_idx[-10:]], rfc.feature_importances_[sorted_idx[-10:]])
# Out:
# <BarContainer object of 10 artists>

# %%
# Classifying selected window of GWAS data using MiniRocket

results = []
for n in range(0,10):
    xTrain, xTest, yTrain, yTest = train_test_split(dfTest.iloc[:, np.r_[1650:1725]], phenotype, train_size=0.7, random_state=1)
    
    xTrain = from_2d_array_to_nested(xTrain)
    xTest = from_2d_array_to_nested(xTest)
    
    minirocket = MiniRocket()
    minirocket.fit(xTrain)
    xTrainTransform = minirocket.transform(xTrain)

    classifier = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10), normalize=True)
    classifier.fit(xTrainTransform, yTrain)

    xTestTransform = minirocket.transform(xTest)
    yPredict = classifier.predict(xTestTransform)

    results.append(accuracy_score(yTest, yPredict))
    
print(f"Average accuracy for MiniRocket on selected SNP window: {sum(results) / len(results)}")
# Out:
# Average accuracy for MiniRocket on selected SNP window: 0.7272727272727274
