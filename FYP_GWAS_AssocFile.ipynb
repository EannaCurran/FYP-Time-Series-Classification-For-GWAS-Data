# %%
import pandas as pd
import numpy as np

# %%
with open("SecondGWAS2.assoc") as f:
    lines = f.readlines()

# %%
values = []
for index, line in enumerate(lines):
    if index == 0:
        sep = line.strip().split(" ")
        n = [x for x in sep if x]
        header = n
    else:    
        sep = line.strip().split(" ")
        n = [x for x in sep if x]
        values.append(n)

# %%
df["P"] = df["P"].apply(pd.to_numeric)

# %%
df = pd.DataFrame(values, columns=header)

# %%
df.sort_values(by="P",ascending=True).head(20)
# Out:
#       CHR        SNP         BP A1      F_A      F_U A2  CHISQ         P  \
# 1681    3  rs1097157   82780003  2   0.5741   0.2545  4  22.95  0.000002
# 1683    3  rs1840290   82785436  2   0.5741   0.2545  4  22.95  0.000002
# 1680    3  rs1598120   82776690  3    0.566     0.25  1  22.15  0.000003
# 1666    3   rs834858   82742725  4   0.5648   0.2545  2  21.72  0.000003
# 1667    3   rs834864   82745840  4   0.5648   0.2545  2  21.72  0.000003
# 1684    3   rs834843   82789058  1   0.5648   0.2545  3  21.72  0.000003
# 1653    3  rs2085079   82721775  4   0.5648   0.2545  2  21.72  0.000003
# 1665    3   rs834856   82741536  4   0.5648   0.2593  2  20.81  0.000005
# 1687    3  rs1580295   82798033  1   0.5648   0.2636  3  20.39  0.000006
# 1690    3  rs1600058   82815522  3   0.5648   0.2636  1  20.39  0.000006
# 1682    3  rs2873392   82780674  4   0.3519      0.1  2  19.84  0.000008
# 23309   3  rs7624706  150450025  4  0.07547   0.3148  2  19.43  0.000010
# ...

# %%
df.sort_values(by="P",ascending=True).head(20)

# %%
df[1650:1700].sort_values(by="P",ascending=True)
# Out:
# Empty DataFrame
# Columns: [CHR, SNP, BP, A1, F_A, F_U, A2, CHISQ, P, OR]
# Index: []
